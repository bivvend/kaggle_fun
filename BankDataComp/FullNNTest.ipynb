# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import lightgbm as lgb
from sklearn.model_selection import KFold, StratifiedKFold
import warnings
import gc
import time
import sys
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error, roc_auc_score, roc_curve
from sklearn.preprocessing import StandardScaler
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings('ignore')

# %%
train= pd.read_csv("../input/train.csv")
test= pd.read_csv("../input/test.csv")

# %%
feats = ["var_{}".format(i) for i in range(200)]
X = train[feats]
X_test = test[feats]
y = train["target"]

cvlist = list(StratifiedKFold(5, random_state=12345786).split(X, y))
scaler = StandardScaler()

X_sc = scaler.fit_transform(X)
X_test_sc = scaler.fit_transform(X_test)

# %%
import keras
from keras.layers import (Flatten, Conv1D, Conv2D, Input, Dense, Dropout, BatchNormalization,
                          concatenate, GaussianNoise, Reshape, TimeDistributed, LeakyReLU, PReLU, Embedding)
from keras.models import Model, load_model, save_model
from keras.optimizers import SGD, Adam
from sklearn.base import BaseEstimator, ClassifierMixin
from pathlib import Path
from keras.callbacks import Callback

class ROC_AUC(Callback):
    def __init__(self, validation_data):
        self.X_val, self.y_val = validation_data
    
    def on_epoch_end(self, epoch, logs={}):
        print("ROC AUC for this fold is ", roc_auc_score(self.y_val, self.model.predict(X_val)))
        
class NNv1(BaseEstimator, ClassifierMixin):
    def __init__(self,
                 inp_shape=200,
                 gaussian_noise=0.01,
                 dense1_dim=32,
                 dense2_dim=32,
                 dense1_kwargs=None,
                 dense2_kwargs=None,
                 classifier_kwargs=None,
                 optimizer=SGD,
                 opt_kwargs=None,
                 ):
        self.inp_shape = inp_shape
        self.gaussian_noise = gaussian_noise
        self.dense1_dim = dense1_dim
        self.dense2_dim = dense2_dim
        self.dense1_kwargs = dense1_kwargs
        self.dense2_kwargs = dense2_kwargs
        self.classifier_kwargs = classifier_kwargs
        self.optimizer = optimizer
        self.opt_kwargs = opt_kwargs
        self._default_initiaization()

    def _default_initiaization(self):
        if self.dense1_kwargs is None:
            self.dense1_kwargs = {"kernel_initializer": "glorot_uniform"}
        if self.dense2_kwargs is None:
            self.dense2_kwargs = {"kernel_initializer": "he_uniform"}
        if self.classifier_kwargs is None:
            self.classifier_kwargs = {"kernel_initializer": "he_uniform"}
        if self.opt_kwargs is None:
            self.opt_kwargs = {}

    def _build_model(self):
        inp = Input(shape=(self.inp_shape,))
        # x = GaussianNoise(self.gaussian_noise)(inp)
        x = Reshape((self.inp_shape, 1))(inp)
        d1 = Dense(self.dense1_dim, activation='tanh',)(x)
        #d1 = TimeDistributed(Dropout(0.2))(d1)
        d2 = Dense(self.dense1_dim, activation='relu',)(x)
        #d2 = PReLU()(d2)
        #d2 = TimeDistributed(Dropout(0.2))(d2)
        x = concatenate([d1, d2])
        x = Flatten()(x)
        out = Dense(1, activation='sigmoid', **self.classifier_kwargs)(x)

        model = Model(inputs=inp, outputs=out)
        opt = self.optimizer(**self.opt_kwargs)
        model.compile(loss='binary_crossentropy', optimizer=opt)
        return model

    def fit(self, X, y, *args, **kwargs):
        self.model = self._build_model()
        print(self.model.summary())
        self.model.fit(X, y, *args, **kwargs)
        return self

    def predict(self, X, y=None, weight_path=None, **kwargs):
        if self.model:
            if weight_path is not None:
                self.model.load_weights(weight_path)
            y_hat = self.model.predict(X, **kwargs)
        else:
            raise ValueError("Model not fit yet")
        return y_hat

# %%
model = NNv1(opt_kwargs = {"lr": 0.01, "momentum": 0.9, "nesterov": True, "clipnorm": 1})
y_preds_nn = np.zeros((len(y)))

for tr_idx, val_idx in cvlist:
    print("Fold {}".format(tr_idx))
    X_dev, y_dev = X_sc[tr_idx], y.iloc[tr_idx]
    X_val, y_val = X_sc[val_idx], y.iloc[val_idx]
    roc_auc = ROC_AUC((X_val, y_val))    
    model.fit(X_dev, y_dev, validation_data=(X_val, y_val), epochs=20, batch_size=256, verbose=0, callbacks=[roc_auc])
    val_preds = model.predict(X_val, batch_size=5000)
    y_preds_nn[val_idx] = val_preds.flatten()
    
sub = pd.DataFrame({"ID_code": test.ID_code.values})
output_df = pd.DataFrame({"ID_code": train.ID_code.values})
y_test_preds = model.predict(X_test_sc, batch_size = 5000)
sub['target'] = y_test_preds.flatten()
sub.to_csv('submission_full_nn.csv')
# Out:
# Fold [ 39913  39914  39915 ... 199997 199998 199999]
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 200)          0
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 200, 1)       0           input_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 200, 32)      64          reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 200, 32)      64          reshape_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 200, 64)      0           dense_4[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 12800)        0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            12801       flatten_2[0][0]
# ==================================================================================================
# Total params: 12,929
# Trainable params: 12,929
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# ROC AUC for this fold is  0.8538155571604196
# ROC AUC for this fold is  0.8704275376957518
# ROC AUC for this fold is  0.8786518824680963
# ROC AUC for this fold is  0.8821219456482076
# ROC AUC for this fold is  0.8870251691709596
# ROC AUC for this fold is  0.8882430037356643
# ROC AUC for this fold is  0.8901118867185429
# ROC AUC for this fold is  0.891927480105932
# ROC AUC for this fold is  0.8932558968034677
# ROC AUC for this fold is  0.8936999640910537
# ROC AUC for this fold is  0.8944156092055772
# ROC AUC for this fold is  0.8943593536998036
# ROC AUC for this fold is  0.8946490726656315
# ROC AUC for this fold is  0.8949633070577188
# ROC AUC for this fold is  0.8955849590877221
# ROC AUC for this fold is  0.8956529399637536
# ROC AUC for this fold is  0.8957721294585961
# ROC AUC for this fold is  0.8957990577116364
# ROC AUC for this fold is  0.8960847287975785
# ROC AUC for this fold is  0.8962981049561675
# Fold [     0      1      2 ... 199997 199998 199999]
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 200)          0
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 200, 1)       0           input_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 200, 32)      64          reshape_3[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 200, 32)      64          reshape_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 200, 64)      0           dense_7[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 12800)        0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1)            12801       flatten_3[0][0]
# ==================================================================================================
# Total params: 12,929
# Trainable params: 12,929
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# ROC AUC for this fold is  0.856571392502483
# ROC AUC for this fold is  0.8725282421720364
# ROC AUC for this fold is  0.8788424715863722
# ROC AUC for this fold is  0.8821900924492903
# ROC AUC for this fold is  0.8841583645376132
# ROC AUC for this fold is  0.8856292244345101
# ROC AUC for this fold is  0.8866991886679827
# ROC AUC for this fold is  0.8880827892720052
# ROC AUC for this fold is  0.889449067992076
# ROC AUC for this fold is  0.8902260604373701
# ROC AUC for this fold is  0.8906335239673897
# ROC AUC for this fold is  0.8904860165972063
# ROC AUC for this fold is  0.8910607740597201
# ROC AUC for this fold is  0.8916366031215203
# ROC AUC for this fold is  0.8917880892361516
# ROC AUC for this fold is  0.8922123353937076
# ROC AUC for this fold is  0.891903953316434
# ROC AUC for this fold is  0.8923043477479339
# ROC AUC for this fold is  0.8927327558588483
# ROC AUC for this fold is  0.8927584120198319
# Fold [     0      1      2 ... 199997 199998 199999]
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 200)          0
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 200, 1)       0           input_4[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 200, 32)      64          reshape_4[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 200, 32)      64          reshape_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 200, 64)      0           dense_10[0][0]
#                                                                  dense_11[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 12800)        0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1)            12801       flatten_4[0][0]
# ==================================================================================================
# Total params: 12,929
# Trainable params: 12,929
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# ROC AUC for this fold is  0.8562413820281582
# ROC AUC for this fold is  0.8734022356256514
# ROC AUC for this fold is  0.882178386831822
# ROC AUC for this fold is  0.8856778572396494
# ROC AUC for this fold is  0.8883023839944247
# ROC AUC for this fold is  0.8905656611329125
# ROC AUC for this fold is  0.8918386181930813
# ROC AUC for this fold is  0.8935260087832102
# ROC AUC for this fold is  0.8944450171322378
# ROC AUC for this fold is  0.8950849698146289
# ROC AUC for this fold is  0.8957440977436331
# ROC AUC for this fold is  0.8959224825013342
# ROC AUC for this fold is  0.8960618081078763
# ROC AUC for this fold is  0.8962541966377119
# ROC AUC for this fold is  0.896878462053269
# ROC AUC for this fold is  0.8970336270288358
# ROC AUC for this fold is  0.8970532793232282
# ROC AUC for this fold is  0.8971782174452917
# ROC AUC for this fold is  0.8977339469965349
# ROC AUC for this fold is  0.8979539247896151
# Fold [     0      1      2 ... 199997 199998 199999]
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 200)          0
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 200, 1)       0           input_5[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 200, 32)      64          reshape_5[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 200, 32)      64          reshape_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 200, 64)      0           dense_13[0][0]
#                                                                  dense_14[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 12800)        0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1)            12801       flatten_5[0][0]
# ==================================================================================================
# Total params: 12,929
# Trainable params: 12,929
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# ROC AUC for this fold is  0.8643136354401088
# ROC AUC for this fold is  0.8789723763485312
# ROC AUC for this fold is  0.8852491175532121
# ROC AUC for this fold is  0.8881679103192577
# ROC AUC for this fold is  0.8896766000740508
# ROC AUC for this fold is  0.8916804053729775
# ROC AUC for this fold is  0.8929551556178192
# ROC AUC for this fold is  0.8932648816122308
# ROC AUC for this fold is  0.8944579845234856
# ROC AUC for this fold is  0.8945945129174497
# ROC AUC for this fold is  0.895086872652289
# ROC AUC for this fold is  0.8951220481202338
# ROC AUC for this fold is  0.8951689314555196
# ROC AUC for this fold is  0.8953954472232437
# ROC AUC for this fold is  0.8954077740239146
# ROC AUC for this fold is  0.895612046226782
# ROC AUC for this fold is  0.8960760940839517
# ROC AUC for this fold is  0.896121203604723
# ROC AUC for this fold is  0.8961477520410625
# ROC AUC for this fold is  0.8964209091031055
# Fold [     0      1      2 ... 160290 160291 160304]
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 200)          0
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 200, 1)       0           input_6[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 200, 32)      64          reshape_6[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 200, 32)      64          reshape_6[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 200, 64)      0           dense_16[0][0]
#                                                                  dense_17[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 12800)        0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 1)            12801       flatten_6[0][0]
# ==================================================================================================
# Total params: 12,929
# Trainable params: 12,929
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# ROC AUC for this fold is  0.8641556553010222
# ROC AUC for this fold is  0.8811776392596534
# ROC AUC for this fold is  0.8870291075700595
# ROC AUC for this fold is  0.8907396785778945
# ROC AUC for this fold is  0.8923944780912124
# ROC AUC for this fold is  0.8946666895337752
# ROC AUC for this fold is  0.8956129901865527
# ROC AUC for this fold is  0.8967840500811807
# ROC AUC for this fold is  0.8967885935359018
# ROC AUC for this fold is  0.8977466297178452
# ROC AUC for this fold is  0.8975317872401811
# ROC AUC for this fold is  0.8978163617204051
# ROC AUC for this fold is  0.8983788960470007
# ROC AUC for this fold is  0.8984574417984833
# ROC AUC for this fold is  0.89834645909971
# ROC AUC for this fold is  0.8988498178676303
# ROC AUC for this fold is  0.8990117259858363
# ROC AUC for this fold is  0.8989983653244642
# ROC AUC for this fold is  0.8992729435127557
# ROC AUC for this fold is  0.8995048948290506
