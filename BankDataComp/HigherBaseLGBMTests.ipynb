# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold

train_df = pd.read_csv('../input/train.csv')
test_df = pd.read_csv('../input/test.csv')
features = [c for c in train_df.columns if c not in ['ID_code', 'target']] #basic features
target = train_df['target']

random_state = 42
np.random.seed(random_state)

params = {
    "objective" : "binary",
    "metric" : "auc",
    "boosting": 'gbdt',
    "max_depth" : -1,
    "num_leaves" : 13,
    "learning_rate" : 0.01,
    "bagging_freq": 5,
    "bagging_fraction" : 0.4,
    "feature_fraction" : 0.05,
    "min_data_in_leaf": 80,
    "min_sum_heassian_in_leaf": 10,
    "tree_learner": "serial",
    "boost_from_average": "false",
    "bagging_seed" : random_state,
    "verbosity" : 1,
    "seed": random_state
}
folds = StratifiedKFold(n_splits=11, shuffle=False, random_state=99999)
oof = np.zeros(len(train_df))
predictions = np.zeros(len(test_df))
train_preds = np.zeros(len(train_df))
for fold_, (trn_idx, val_idx) in enumerate(folds.split(train_df.values, target.values)):
    print("Fold {}".format(fold_))
    trn_data = lgb.Dataset(train_df.iloc[trn_idx][features], label=target.iloc[trn_idx])
    val_data = lgb.Dataset(train_df.iloc[val_idx][features], label=target.iloc[val_idx])
    clf = lgb.train(params, trn_data, 1000000, valid_sets = [trn_data, val_data], verbose_eval=5000, early_stopping_rounds = 2000)
    oof[val_idx] = clf.predict(train_df.iloc[val_idx][features], num_iteration=clf.best_iteration)
    predictions += clf.predict(test_df[features], num_iteration=clf.best_iteration) / folds.n_splits
    train_preds += clf.predict(train_df[features], num_iteration=clf.best_iteration) / folds.n_splits
print("CV score: {:<8.5f}".format(roc_auc_score(target, oof)))
sub = pd.DataFrame({"ID_code": test_df.ID_code.values})
sub["target"] = predictions
sub.to_csv("submission_lgbm_base3.csv", index=False)

sub_lgb = pd.DataFrame({"ID_code": train_df.ID_code.values})
sub_lgb["output"] = train_preds
sub_lgb.to_csv("../input/output_lgbm_base3.csv")
# Out:
# Fold 0
# Training until validation scores don't improve for 2000 rounds.
# [5000]	training's auc: 0.929796	valid_1's auc: 0.897779
# [10000]	training's auc: 0.949515	valid_1's auc: 0.900488
# Early stopping, best iteration is:
# [9884]	training's auc: 0.949131	valid_1's auc: 0.900538
# Fold 1
# Training until validation scores don't improve for 2000 rounds.
# [5000]	training's auc: 0.929828	valid_1's auc: 0.896762
# [10000]	training's auc: 0.949518	valid_1's auc: 0.897878
# Early stopping, best iteration is:
# [10926]	training's auc: 0.952614	valid_1's auc: 0.898093
# Fold 2
# Training until validation scores don't improve for 2000 rounds.
# [5000]	training's auc: 0.930145	valid_1's auc: 0.891151
# [10000]	training's auc: 0.949765	valid_1's auc: 0.893272
# Early stopping, best iteration is:
# [10296]	training's auc: 0.950782	valid_1's auc: 0.893407
# Fold 3
# Training until validation scores don't improve for 2000 rounds.
# [5000]	training's auc: 0.929479	valid_1's auc: 0.900985
# [10000]	training's auc: 0.949285	valid_1's auc: 0.90176
# Early stopping, best iteration is:
# [8665]	training's auc: 0.94455	valid_1's auc: 0.901988
# Fold 4
# Training until validation scores don't improve for 2000 rounds.
# [5000]	training's auc: 0.929883	valid_1's auc: 0.897336
# [10000]	training's auc: 0.949505	valid_1's auc: 0.898455
# Early stopping, best iteration is:
# [8782]	training's auc: 0.94523	valid_1's auc: 0.898666
# Fold 5
# Training until validation scores don't improve for 2000 rounds.
# [5000]	training's auc: 0.929682	valid_1's auc: 0.900347
# [10000]	training's auc: 0.949273	valid_1's auc: 0.90156
# Early stopping, best iteration is:
# [10774]	training's auc: 0.951912	valid_1's auc: 0.901796
# Fold 6
# Training until validation scores don't improve for 2000 rounds.
# [5000]	training's auc: 0.92944	valid_1's auc: 0.903886
# Early stopping, best iteration is:
# [7271]	training's auc: 0.939147	valid_1's auc: 0.904699
# Fold 7
# Training until validation scores don't improve for 2000 rounds.
# [5000]	training's auc: 0.929824	valid_1's auc: 0.895886
# [10000]	training's auc: 0.949383	valid_1's auc: 0.897289
# Early stopping, best iteration is:
# [9481]	training's auc: 0.947573	valid_1's auc: 0.897449
# Fold 8
# Training until validation scores don't improve for 2000 rounds.
# [5000]	training's auc: 0.929335	valid_1's auc: 0.901651
# [10000]	training's auc: 0.949264	valid_1's auc: 0.903191
# Early stopping, best iteration is:
# [8274]	training's auc: 0.943023	valid_1's auc: 0.903294
# Fold 9
# Training until validation scores don't improve for 2000 rounds.
# [5000]	training's auc: 0.929237	valid_1's auc: 0.90362
# Early stopping, best iteration is:
# [7721]	training's auc: 0.940656	valid_1's auc: 0.904949
# Fold 10
# Training until validation scores don't improve for 2000 rounds.
# [5000]	training's auc: 0.929979	valid_1's auc: 0.898498
# [10000]	training's auc: 0.949701	valid_1's auc: 0.899938
# Early stopping, best iteration is:
# [10406]	training's auc: 0.951099	valid_1's auc: 0.900068
# CV score: 0.90027
