# %%
import gc
import os
import logging
import datetime
import warnings
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import StratifiedKFold
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def process_data(train_df, test_df):    
    idx = [c for c in train_df.columns if c not in ['ID_code', 'target']]
    var_info_df = pd.DataFrame(index = idx)
    means = []
    stds = []
    kurts = []
    skews = []
    for feat in idx:
            mean = train_df.loc[:,feat].mean()
            std = train_df.loc[:,feat].std()
            kurt = train_df.loc[:,feat].kurtosis()
            skew = train_df.loc[:,feat].skew()
            means.append(mean)
            stds.append(std)
            kurts.append(kurt)
            skews.append(skew)
    var_info_df["means"] = means
    var_info_df["stds"] = stds
    var_info_df["kurts"] = kurts
    var_info_df["skews"] = skews
    
#     var_info_df.plot.scatter(x = 'means', y = 'stds')
#     var_info_df.plot.scatter(x = 'means', y = 'means')
#     var_info_df.plot.scatter(x = 'means', y = 'kurts')
#     var_info_df.plot.scatter(x = 'means', y = 'skews')
    var_info_df.to_csv("variable-means-etc.csv", index=False)
            
    for df in [test_df, train_df]:
        for feat in idx:
            mean = df.loc[:,feat].mean()
#             print("Mean feat {0} = {1}".format(feat, mean)) 
            #enhance large features
            if mean > 7 or mean < -7:
                df['r2_'+feat] = np.round(df[feat], 2)
                df['r2mm_'+feat] = np.round(df[feat] - mean, 2) 
                df['r2mmsq_'+feat] = np.round(df[feat]*df[feat], 2)
                print(mean)
            else:
                df['r2_' +feat] = 0 #np.round(df[feat] - df[feat] , 2)    #zero
                df['r2mm_'+feat] = 0 #np.round(df[feat] - df[feat] , 2)    #zero
                df['r2mmsq_'+feat] = 0
                print("0")
#         df['sum'] = df[idx].sum(axis=1)  
#         df['min'] = df[idx].min(axis=1)
#         df['max'] = df[idx].max(axis=1)
#         df['mean'] = df[idx].mean(axis=1)
#         df['std'] = df[idx].std(axis=1)
#         df['skew'] = df[idx].skew(axis=1)
#         df['kurt'] = df[idx].kurtosis(axis=1)
#         df['med'] = df[idx].median(axis=1)
        
#         #plot the data
#         df.plot.scatter(x='mean', y='kurt')
#         df.plot.scatter(x='mean', y='std')
    
    print('Train and test shape:',train_df.shape, test_df.shape)
    #train_df.head(10)
    return train_df, test_df

# %%
def run_model(train_df, test_df):
    features = [c for c in train_df.columns if c not in ['ID_code', 'target']]
    target = train_df['target']
    param = {
            'num_leaves': 15, #was 10
            'max_bin': 119,
            'min_data_in_leaf': 11,
            'learning_rate': 0.01,
            'min_sum_hessian_in_leaf': 0.00245,
            'bagging_fraction': 1.0, 
            'bagging_freq': 5, 
            'feature_fraction': 0.05,
            'lambda_l1': 4.972,
            'lambda_l2': 2.276,
            'min_gain_to_split': 0.65,
            'max_depth': 20, #was 14
            'save_binary': True,
            'seed': 1337,
            'feature_fraction_seed': 1337,
            'bagging_seed': 1337,
            'drop_seed': 1337,
            'data_random_seed': 1337,
            'objective': 'binary',
            'boosting_type': 'gbdt',
            'verbose': 1,
            'metric': 'auc',
            'is_unbalance': True,
            'boost_from_average': True, #was false
        }
    num_round = 15000
    folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=2019)
    oof = np.zeros(len(train_df))
    predictions = np.zeros(len(test_df))
    for fold_, (trn_idx, val_idx) in enumerate(folds.split(train_df.values, target.values)):
        print("Fold {}".format(fold_))
        trn_data = lgb.Dataset(train_df.iloc[trn_idx][features], label=target.iloc[trn_idx])
        val_data = lgb.Dataset(train_df.iloc[val_idx][features], label=target.iloc[val_idx])
        clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds = 800)
        oof[val_idx] = clf.predict(train_df.iloc[val_idx][features], num_iteration=clf.best_iteration)
        predictions += clf.predict(test_df[features], num_iteration=clf.best_iteration) / folds.n_splits
    print("CV score: {:<8.5f}".format(roc_auc_score(target, oof)))
    return predictions

# %%
print(os.listdir("../input"))
train=pd.read_csv("../input/train.csv")
print("Training dataset")
print("----------------")
train.info()

test=pd.read_csv("../input/test.csv")
print("Test dataset")
print("----------------")
test.info()

features = [c for c in train.columns if c not in ['ID_code', 'target']]
target = train['target']

train_df, test_df = process_data(train, test)
predictions = run_model(train_df, test_df)
sub = pd.DataFrame({"ID_code": test_df.ID_code.values})
sub["target"] = predictions
sub.to_csv("submission.csv", index=False)
# Out:
# ['sample_submission.csv', 'test.csv', 'train.csv']
# Training dataset
# ----------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 202 entries, ID_code to var_199
# dtypes: float64(200), int64(1), object(1)
# memory usage: 308.2+ MB
# Test dataset
# ----------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 201 entries, ID_code to var_199
# dtypes: float64(200), object(1)
# memory usage: 306.7+ MB
# 10.658737106499999
# 0
# 10.707451979500002
# 0
# 11.076399133
# 0
# 0
# 16.5291427375
# 0
# 7.5694074580000015
# 0
# 0
# 14.022661509499999
# 8.5408719795
# 7.5327026615
# 14.573703906
# 9.321668816500003
# 0
# 15.265776456
# 12.456674780000004
# 13.298428218999998
# 17.230597854000003
# 0
# 0
# 10.567479188500002
# 13.666969998500004
# 0
# 0
# 0
# 0
# -7.687695017499999
# 10.404919847499999
# 0
# 14.7626855595
# 11.434860582
# 0
# 0
# 0
# 10.647806177000001
# 0
# 0
# 9.2706456065
# 11.22173246
# 11.5689723895
# 8.952581144
# -12.666094574499999
# 11.299741331999998
# -12.455576731
# 14.685614812
# 16.6872799665
# 12.745665609499998
# 13.391711324499997
# 0
# 0
# 0
# 12.756875691000001
# 16.60444682
# 0
# 0
# 8.9280522685
# 12.161970846500001
# -11.9560226685
# 0
# 0
# 0
# 0
# 0
# 11.8815998665
# 0
# 0
# 24.442541174500004
# 0
# 0
# 19.6135970825
# 19.445254125499996
# 16.8765252825
# 0
# 19.071853438
# 0
# 14.407223958000001
# 0
# 14.729931027000001
# 0
# 0
# 0
# 18.3867198775
# 0
# 11.379620979499999
# 8.738048596
# 0
# -16.334975914500003
# 0
# 12.735526502
# 10.55692098
# 10.989159386
# 0
# 14.42537845
# 18.603350450499995
# 0
# 0
# 0
# 13.3893220515
# 22.334372398499994
# 0
# 11.523125318000002
# 0
# 8.6210514025
# 17.8242767245
# 14.2251070155
# 18.455456877499998
# 0
# 0
# 0
# 8.145249961500001
# 0
# 0
# 0
# 16.0399246055
# 0
# 0
# 24.536098971499996
# 11.312734970500001
# 0
# 7.023936041000002
# 0
# 12.488117265999996
# 13.205603369500002
# 0
# 0
# 15.435012127
# 12.256858181500002
# 0
# 7.801596687999998
# 0
# 0
# 0
# 23.019124850000004
# 17.6474455985
# 0
# 7.765887636500001
# 0
# 0
# 11.971068055999998
# 12.335212781
# 8.644855877999998
# 0
# 10.3622142035
# 0
# 0
# 0
# 16.820051007
# 10.156002283
# 7.628823997500001
# 16.721077255
# 0
# 0
# 13.208797351500001
# 0
# 17.924734242
# 10.239228836999999
# 24.146181414
# 0
# 0
# 11.026376490499999
# 0
# 19.3207604395
# 0
# 0
# 0
# 0
# 0
# 0
# 19.779527723999994
# 0
# 20.264134910500005
# 11.635714910500003
# 0
# 11.864537785500003
# 0
# 0
# 0
# 10.080827214500003
# 0
# 8.768929472000002
# 12.719302336499998
# 0
# 8.978800128
# -10.2919186855
# 15.366094265000001
# 0
# 0
# 7.458269406000001
# 0
# 0
# 17.996966972
# 0
# 0
# 8.912428147499998
# 15.8691836065
# 0
# 10.679914251999998
# 0
# 10.715191851000002
# 0
# 11.078333240500001
# 0
# 0
# 16.545849889499998
# 0
# 7.567236361499998
# 0
# 0
# 14.023977798499999
# 8.530232378999997
# 7.5376061135000025
# 14.573125859000001
# 9.333264182500002
# 0
# 15.244013001999999
# 12.438567329499998
# 13.2908941205
# 17.257882793000004
# 0
# 0
# 10.584400070500001
# 13.667496002999997
# 0
# 0
# 0
# 0
# -7.6877395945000035
# 10.393045872000002
# 0
# 14.7741467185
# 11.434249707999998
# 0
# 0
# 0
# 10.642130851000001
# 0
# 0
# 9.299858002
# 11.222356093500002
# 11.5699539
# 8.948288796500002
# -12.6996668205
# 11.326487955999998
# -12.471737158499996
# 14.7047127185
# 16.6824987025
# 12.740985916
# 13.428911726
# 0
# 0
# 0
# 12.745851658000001
# 16.629164889000002
# 0
# 0
# 8.9311241245
# 12.155618231499998
# -11.946744154000001
# 0
# 0
# 0
# 0
# 0
# 11.943223381000001
# 0
# 0
# 24.446811051000005
# 0
# 0
# 19.610887772499996
# 19.518845928
# 16.853731765000003
# 0
# 19.066992556
# 0
# 14.402136341500002
# 0
# 14.7190238585
# 0
# 0
# 0
# 18.362720644499994
# 0
# 11.351483195500002
# 8.702923521499999
# 0
# -16.548147024000002
# 0
# 12.739578443
# 10.556739837000002
# 10.999161667
# 0
# 14.400433117
# 18.5396446215
# 0
# 0
# 0
# 13.4135261765
# 22.294908152
# 0
# 11.509834017999996
# 0
# 8.617657006000002
# 17.7962655475
# 14.224435357
# 18.4580011445
# 0
# 0
# 0
# 8.136541668
# 0
# 0
# 0
# 16.102233313000003
# 0
# 0
# 24.521077860500007
# 11.310591073500001
# 0
# 7.076253564999999
# 0
# 12.489164999000002
# 13.202325819000004
# 0
# 0
# 15.4603143455
# 12.257150888500004
# 0
# 7.799675918000002
# 0
# 0
# 0
# 22.968601605000003
# 17.613651327499998
# 0
# 7.760193281
# 0
# 0
# 11.983488539999998
# 12.333697980500004
# 8.647631575
# 0
# 10.3411778935
# 0
# 0
# 0
# 16.817671238000003
# 10.141541544499997
# 7.633199000499999
# 16.727902174999997
# 0
# 0
# 13.209272123499996
# 0
# 17.914590597500002
# 10.223282276499999
# 24.259300121
# 0
# 0
# 11.002169658000001
# 0
# 19.315753234000002
# 0
# 0
# 0
# 0
# 0
# 0
# 19.817093824999997
# 0
# 20.210676787999997
# 11.640612669500003
# 0
# 11.8829333875
# 0
# 0
# 0
# 10.085518355
# 0
# 8.769087543499998
# 12.756676405999999
# 0
# 8.970274164500001
# -10.335042614
# 15.377174498999999
# 0
# 0
# 7.438408336999999
# 0
# 0
# 17.993784183000002
# 0
# 0
# 8.9081576835
# 15.870720248
# 0
# Train and test shape: (200000, 802) (200000, 801)
# Fold 0
# Training until validation scores don't improve for 800 rounds.
# [1000]	training's auc: 0.892412	valid_1's auc: 0.869232
# [2000]	training's auc: 0.917939	valid_1's auc: 0.887126
# [3000]	training's auc: 0.930542	valid_1's auc: 0.893422
# [4000]	training's auc: 0.939086	valid_1's auc: 0.896528
# [5000]	training's auc: 0.945828	valid_1's auc: 0.898175
# [6000]	training's auc: 0.951702	valid_1's auc: 0.898914
# [7000]	training's auc: 0.957073	valid_1's auc: 0.899217
# [8000]	training's auc: 0.962008	valid_1's auc: 0.899302
# [9000]	training's auc: 0.966435	valid_1's auc: 0.899269
# Early stopping, best iteration is:
# [8322]	training's auc: 0.963492	valid_1's auc: 0.89937
# Fold 1
# Training until validation scores don't improve for 800 rounds.
# [1000]	training's auc: 0.892968	valid_1's auc: 0.866115
# [2000]	training's auc: 0.918264	valid_1's auc: 0.883322
# [3000]	training's auc: 0.930814	valid_1's auc: 0.890001
# [4000]	training's auc: 0.939284	valid_1's auc: 0.893225
# [5000]	training's auc: 0.946083	valid_1's auc: 0.895122
# [6000]	training's auc: 0.951866	valid_1's auc: 0.896035
# [7000]	training's auc: 0.957226	valid_1's auc: 0.896603
# [8000]	training's auc: 0.962152	valid_1's auc: 0.896812
# [9000]	training's auc: 0.966547	valid_1's auc: 0.896926
# [10000]	training's auc: 0.970478	valid_1's auc: 0.896852
# Early stopping, best iteration is:
# [9298]	training's auc: 0.967764	valid_1's auc: 0.896936
# Fold 2
# Training until validation scores don't improve for 800 rounds.
# [1000]	training's auc: 0.891993	valid_1's auc: 0.867473
# [2000]	training's auc: 0.917685	valid_1's auc: 0.885911
# [3000]	training's auc: 0.93028	valid_1's auc: 0.89287
# [4000]	training's auc: 0.938894	valid_1's auc: 0.896106
# [5000]	training's auc: 0.945719	valid_1's auc: 0.897867
# [6000]	training's auc: 0.951614	valid_1's auc: 0.898991
# [7000]	training's auc: 0.95698	valid_1's auc: 0.899381
# [8000]	training's auc: 0.96188	valid_1's auc: 0.899577
# [9000]	training's auc: 0.966314	valid_1's auc: 0.89973
# [10000]	training's auc: 0.970277	valid_1's auc: 0.899801
# Early stopping, best iteration is:
# [9801]	training's auc: 0.969518	valid_1's auc: 0.899832
# Fold 3
# Training until validation scores don't improve for 800 rounds.
# [1000]	training's auc: 0.893449	valid_1's auc: 0.862735
# [2000]	training's auc: 0.918836	valid_1's auc: 0.880883
# [3000]	training's auc: 0.931504	valid_1's auc: 0.887612
# [4000]	training's auc: 0.940176	valid_1's auc: 0.890806
# [5000]	training's auc: 0.946906	valid_1's auc: 0.892411
# [6000]	training's auc: 0.95272	valid_1's auc: 0.89324
# [7000]	training's auc: 0.958021	valid_1's auc: 0.893715
# [8000]	training's auc: 0.96282	valid_1's auc: 0.893911
# [9000]	training's auc: 0.967142	valid_1's auc: 0.893962
# Early stopping, best iteration is:
# [8642]	training's auc: 0.96566	valid_1's auc: 0.89399
# Fold 4
# Training until validation scores don't improve for 800 rounds.
# [1000]	training's auc: 0.892735	valid_1's auc: 0.86513
# [2000]	training's auc: 0.918378	valid_1's auc: 0.883556
# [3000]	training's auc: 0.930896	valid_1's auc: 0.89029
# [4000]	training's auc: 0.939425	valid_1's auc: 0.893534
# [5000]	training's auc: 0.946179	valid_1's auc: 0.895263
# [6000]	training's auc: 0.952015	valid_1's auc: 0.89619
# [7000]	training's auc: 0.957387	valid_1's auc: 0.896651
# [8000]	training's auc: 0.962245	valid_1's auc: 0.896789
# [9000]	training's auc: 0.966661	valid_1's auc: 0.896901
# [10000]	training's auc: 0.970524	valid_1's auc: 0.896922
# Early stopping, best iteration is:
# [9695]	training's auc: 0.969387	valid_1's auc: 0.896964
# CV score: 0.89739
