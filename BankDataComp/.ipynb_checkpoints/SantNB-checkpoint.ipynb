# %%
import gc
import os
import logging
import datetime
import warnings
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import StratifiedKFold
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def process_data(train_df, test_df):    
    idx = [c for c in train_df.columns if c not in ['ID_code', 'target']]
    for df in [test_df, train_df]:
        for feat in idx:
            mean = df.loc[:,feat].mean()
            mode = df.loc[:,feat].astype(int).mode()
            print("Mean feat {0} = {1}".format(feat, mean))
            print("Mode feat {0} = {1}".format(feat, mode.iloc[0]))
            #df['r2mm_'+feat] = np.round(df[feat], 2) -  mean 
            if mean > 0.0:
                df['r2mm_' +feat] = np.round(df[feat] - mode.iloc[0], 2)
            else:
                df['r2mm_' +feat] = np.round(df[feat] - mean , 2)
        df['sum'] = df[idx].sum(axis=1)  
        df['min'] = df[idx].min(axis=1)
        df['max'] = df[idx].max(axis=1)
        df['mean'] = df[idx].mean(axis=1)
        df['std'] = df[idx].std(axis=1)
        df['skew'] = df[idx].skew(axis=1)
        df['kurt'] = df[idx].kurtosis(axis=1)
        df['med'] = df[idx].median(axis=1)
    print('Train and test shape:',train_df.shape, test_df.shape)
    train_df.head(10)
    return train_df, test_df

# %%
def run_model(train_df, test_df):
    features = [c for c in train_df.columns if c not in ['ID_code', 'target']]
    target = train_df['target']
    param = {
            'num_leaves': 15, #was 10
            'max_bin': 119,
            'min_data_in_leaf': 11,
            'learning_rate': 0.02,
            'min_sum_hessian_in_leaf': 0.00245,
            'bagging_fraction': 1.0, 
            'bagging_freq': 5, 
            'feature_fraction': 0.05,
            'lambda_l1': 4.972,
            'lambda_l2': 2.276,
            'min_gain_to_split': 0.65,
            'max_depth': 20, #was 14
            'save_binary': True,
            'seed': 1337,
            'feature_fraction_seed': 1337,
            'bagging_seed': 1337,
            'drop_seed': 1337,
            'data_random_seed': 1337,
            'objective': 'binary',
            'boosting_type': 'gbdt',
            'verbose': 1,
            'metric': 'auc',
            'is_unbalance': True,
            'boost_from_average': True, #was false
        }
    num_round = 15000
    folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=2019)
    oof = np.zeros(len(train_df))
    predictions = np.zeros(len(test_df))
    for fold_, (trn_idx, val_idx) in enumerate(folds.split(train_df.values, target.values)):
        print("Fold {}".format(fold_))
        trn_data = lgb.Dataset(train_df.iloc[trn_idx][features], label=target.iloc[trn_idx])
        val_data = lgb.Dataset(train_df.iloc[val_idx][features], label=target.iloc[val_idx])
        clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds = 100)
        oof[val_idx] = clf.predict(train_df.iloc[val_idx][features], num_iteration=clf.best_iteration)
        predictions += clf.predict(test_df[features], num_iteration=clf.best_iteration) / folds.n_splits
    print("CV score: {:<8.5f}".format(roc_auc_score(target, oof)))
    return predictions

# %%
print(os.listdir("../input"))
train=pd.read_csv("../input/train.csv")
print("Training dataset")
print("----------------")
train.info()

test=pd.read_csv("../input/test.csv")
print("Test dataset")
print("----------------")
test.info()

features = [c for c in train.columns if c not in ['ID_code', 'target']]
target = train['target']

train_df, test_df = process_data(train, test)
predictions = run_model(train_df, test_df)
sub = pd.DataFrame({"ID_code": test_df.ID_code.values})
sub["target"] = predictions
sub.to_csv("submission.csv", index=False)
# Out:
# ['sample_submission.csv', 'test.csv', 'train.csv']
# Training dataset
# ----------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 202 entries, ID_code to var_199
# dtypes: float64(200), int64(1), object(1)
# memory usage: 308.2+ MB
# Test dataset
# ----------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 201 entries, ID_code to var_199
# dtypes: float64(200), object(1)
# memory usage: 306.7+ MB
# Mean feat var_0 = 10.658737106499999
# Mode feat var_0 = 9
# Mean feat var_1 = -1.62424378
# Mode feat var_1 = 0
# Mean feat var_2 = 10.707451979500002
# Mode feat var_2 = 9
# Mean feat var_3 = 6.7882139085
# Mode feat var_3 = 7
# Mean feat var_4 = 11.076399133
# Mode feat var_4 = 11
# Mean feat var_5 = -5.050557728999999
# Mode feat var_5 = 0
# Mean feat var_6 = 5.4151641124999985
# Mode feat var_6 = 5
# Mean feat var_7 = 16.5291427375
# Mode feat var_7 = 14
# Mean feat var_8 = 0.27713482600000006
# Mode feat var_8 = 0
# Mean feat var_9 = 7.5694074580000015
# Mode feat var_9 = 7
# Mean feat var_10 = 0.371334995
# Mode feat var_10 = 0
# Mean feat var_11 = -3.2685512850000005
# Mode feat var_11 = 0
# Mean feat var_12 = 14.022661509499999
# Mode feat var_12 = 14
# Mean feat var_13 = 8.5408719795
# Mode feat var_13 = 8
# Mean feat var_14 = 7.5327026615
# Mode feat var_14 = 6
# Mean feat var_15 = 14.573703906
# Mode feat var_15 = 14
# Mean feat var_16 = 9.321668816500003
# Mode feat var_16 = 8
# Mean feat var_17 = -5.704449782000001
# Mode feat var_17 = 0
# Mean feat var_18 = 15.265776456
# Mode feat var_18 = 16
# Mean feat var_19 = 12.456674780000004
# Mode feat var_19 = 13
# Mean feat var_20 = 13.298428218999998
# Mode feat var_20 = 10
# Mean feat var_21 = 17.230597854000003
# Mode feat var_21 = 17
# Mean feat var_22 = 4.299010464
# Mode feat var_22 = 4
# Mean feat var_23 = 3.0197068120000004
# Mode feat var_23 = 3
# Mean feat var_24 = 10.567479188500002
# Mode feat var_24 = 8
# Mean feat var_25 = 13.666969998500004
# Mode feat var_25 = 13
# Mean feat var_26 = -3.9837214164999994
# Mode feat var_26 = 0
# Mean feat var_27 = -1.1295362375
# Mode feat var_27 = 0
# Mean feat var_28 = 5.530656125500001
# Mode feat var_28 = 5
# Mean feat var_29 = 5.047247367500002
# Mode feat var_29 = 4
# Mean feat var_30 = -7.687695017499999
# Mode feat var_30 = 0
# Mean feat var_31 = 10.404919847499999
# Mode feat var_31 = 10
# Mean feat var_32 = -0.5248298400000001
# Mode feat var_32 = 0
# Mean feat var_33 = 14.7626855595
# Mode feat var_33 = 12
# Mean feat var_34 = 11.434860582
# Mode feat var_34 = 11
# Mean feat var_35 = 3.8701297465000004
# Mode feat var_35 = 0
# Mean feat var_36 = 2.2132884390000003
# Mode feat var_36 = 0
# Mean feat var_37 = 5.8750477775
# Mode feat var_37 = 6
# Mean feat var_38 = 10.647806177000001
# Mode feat var_38 = 10
# Mean feat var_39 = 0.6726665784999999
# Mode feat var_39 = 0
# Mean feat var_40 = -6.7360539349999975
# Mode feat var_40 = 0
# Mean feat var_41 = 9.2706456065
# Mode feat var_41 = 8
# Mean feat var_42 = 11.22173246
# Mode feat var_42 = 11
# Mean feat var_43 = 11.5689723895
# Mode feat var_43 = 11
# Mean feat var_44 = 8.952581144
# Mode feat var_44 = 10
# Mean feat var_45 = -12.666094574499999
# Mode feat var_45 = 0
# Mean feat var_46 = 11.299741331999998
# Mode feat var_46 = 11
# Mean feat var_47 = -12.455576731
# Mode feat var_47 = 0
# Mean feat var_48 = 14.685614812
# Mode feat var_48 = 0
# Mean feat var_49 = 16.6872799665
# Mode feat var_49 = 16
# Mean feat var_50 = 12.745665609499998
# Mode feat var_50 = 12
# Mean feat var_51 = 13.391711324499997
# Mode feat var_51 = 15
# Mean feat var_52 = -2.5169432055
# Mode feat var_52 = 0
# Mean feat var_53 = 6.0153554685
# Mode feat var_53 = 6
# Mean feat var_54 = 1.133256832
# Mode feat var_54 = 0
# Mean feat var_55 = 12.756875691000001
# Mode feat var_55 = 11
# Mean feat var_56 = 16.60444682
# Mode feat var_56 = 16
# Mean feat var_57 = 6.273477188
# Mode feat var_57 = 6
# Mean feat var_58 = 3.1901697635
# Mode feat var_58 = 0
# Mean feat var_59 = 8.9280522685
# Mode feat var_59 = 8
# Mean feat var_60 = 12.161970846500001
# Mode feat var_60 = 13
# Mean feat var_61 = -11.9560226685
# Mode feat var_61 = 0
# Mean feat var_62 = 0.882442558
# Mode feat var_62 = 0
# Mean feat var_63 = 0.6732283160000001
# Mode feat var_63 = 0
# Mean feat var_64 = 6.368547547999999
# Mode feat var_64 = 6
# Mean feat var_65 = 0.9763593240000003
# Mode feat var_65 = 0
# Mean feat var_66 = 5.786661653
# Mode feat var_66 = 5
# Mean feat var_67 = 11.8815998665
# Mode feat var_67 = 11
# Mean feat var_68 = 5.018851925999999
# Mode feat var_68 = 5
# Mean feat var_69 = -3.334390129999999
# Mode feat var_69 = 0
# Mean feat var_70 = 24.442541174500004
# Mode feat var_70 = 24
# Mean feat var_71 = 0.6702781419999999
# Mode feat var_71 = 0
# Mean feat var_72 = 0.6487462585000001
# Mode feat var_72 = 0
# Mean feat var_73 = 19.6135970825
# Mode feat var_73 = 15
# Mean feat var_74 = 19.445254125499996
# Mode feat var_74 = 20
# Mean feat var_75 = 16.8765252825
# Mode feat var_75 = 15
# Mean feat var_76 = 6.071364954
# Mode feat var_76 = 0
# Mean feat var_77 = 19.071853438
# Mode feat var_77 = 16
# Mean feat var_78 = 5.348848409500001
# Mode feat var_78 = 6
# Mean feat var_79 = 14.407223958000001
# Mode feat var_79 = 14
# Mean feat var_80 = 5.8150813785
# Mode feat var_80 = 0
# Mean feat var_81 = 14.729931027000001
# Mode feat var_81 = 15
# Mean feat var_82 = -3.4261988549999995
# Mode feat var_82 = 0
# Mean feat var_83 = 1.0215122239999999
# Mode feat var_83 = 0
# Mean feat var_84 = -2.5652808455
# Mode feat var_84 = 0
# Mean feat var_85 = 18.3867198775
# Mode feat var_85 = 18
# Mean feat var_86 = 5.637934724999999
# Mode feat var_86 = 0
# Mean feat var_87 = 11.379620979499999
# Mode feat var_87 = 10
# Mean feat var_88 = 8.738048596
# Mode feat var_88 = 7
# Mean feat var_89 = 3.7287907769999995
# Mode feat var_89 = 0
# Mean feat var_90 = -16.334975914500003
# Mode feat var_90 = 0
# Mean feat var_91 = 6.988214438499999
# Mode feat var_91 = 6
# Mean feat var_92 = 12.735526502
# Mode feat var_92 = 12
# Mean feat var_93 = 10.55692098
# Mode feat var_93 = 10
# Mean feat var_94 = 10.989159386
# Mode feat var_94 = 10
# Mean feat var_95 = -0.08877193900000002
# Mode feat var_95 = 0
# Mean feat var_96 = 14.42537845
# Mode feat var_96 = 15
# Mean feat var_97 = 18.603350450499995
# Mode feat var_97 = 0
# Mean feat var_98 = 1.7516930625
# Mode feat var_98 = 1
# Mean feat var_99 = -0.7456733899999999
# Mode feat var_99 = 0
# Mean feat var_100 = -6.674012936499999
# Mode feat var_100 = 0
# Mean feat var_101 = 13.3893220515
# Mode feat var_101 = 11
# Mean feat var_102 = 22.334372398499994
# Mode feat var_102 = 19
# Mean feat var_103 = 1.5687066325
# Mode feat var_103 = 1
# Mean feat var_104 = 11.523125318000002
# Mode feat var_104 = 11
# Mean feat var_105 = 4.244310818
# Mode feat var_105 = 4
# Mean feat var_106 = 8.6210514025
# Mode feat var_106 = 8
# Mean feat var_107 = 17.8242767245
# Mode feat var_107 = 15
# Mean feat var_108 = 14.2251070155
# Mode feat var_108 = 14
# Mean feat var_109 = 18.455456877499998
# Mode feat var_109 = 15
# Mean feat var_110 = 5.497815813
# Mode feat var_110 = 4
# Mean feat var_111 = 6.313690861999999
# Mode feat var_111 = 6
# Mean feat var_112 = 3.3117930895000005
# Mode feat var_112 = 4
# Mean feat var_113 = 8.145249961500001
# Mode feat var_113 = 6
# Mean feat var_114 = 3.0861618569999996
# Mode feat var_114 = 3
# Mean feat var_115 = 2.1997268670000003
# Mode feat var_115 = 0
# Mean feat var_116 = 2.3920583220000005
# Mode feat var_116 = 2
# Mean feat var_117 = 16.0399246055
# Mode feat var_117 = 0
# Mean feat var_118 = -5.3105242525
# Mode feat var_118 = 0
# Mean feat var_119 = 3.0605411975
# Mode feat var_119 = 0
# Mean feat var_120 = 24.536098971499996
# Mode feat var_120 = 25
# Mean feat var_121 = 11.312734970500001
# Mode feat var_121 = 10
# Mean feat var_122 = 1.1917482575
# Mode feat var_122 = 0
# Mean feat var_123 = 7.023936041000002
# Mode feat var_123 = 0
# Mean feat var_124 = 4.2795790785
# Mode feat var_124 = 4
# Mean feat var_125 = 12.488117265999996
# Mode feat var_125 = 12
# Mean feat var_126 = 13.205603369500002
# Mode feat var_126 = 13
# Mean feat var_127 = 0.8471748654999999
# Mode feat var_127 = 0
# Mean feat var_128 = -1.1326167655000001
# Mode feat var_128 = 0
# Mean feat var_129 = 15.435012127
# Mode feat var_129 = 14
# Mean feat var_130 = 12.256858181500002
# Mode feat var_130 = 12
# Mean feat var_131 = 0.547403289
# Mode feat var_131 = 0
# Mean feat var_132 = 7.801596687999998
# Mode feat var_132 = 7
# Mean feat var_133 = 6.814901699
# Mode feat var_133 = 6
# Mean feat var_134 = -4.806086077
# Mode feat var_134 = 0
# Mean feat var_135 = -4.309017192
# Mode feat var_135 = 0
# Mean feat var_136 = 23.019124850000004
# Mode feat var_136 = 20
# Mean feat var_137 = 17.6474455985
# Mode feat var_137 = 15
# Mean feat var_138 = 1.2432903725
# Mode feat var_138 = 0
# Mean feat var_139 = 7.765887636500001
# Mode feat var_139 = 0
# Mean feat var_140 = 3.411716262
# Mode feat var_140 = 0
# Mean feat var_141 = 2.8732788469999986
# Mode feat var_141 = 0
# Mean feat var_142 = 11.971068055999998
# Mode feat var_142 = 11
# Mean feat var_143 = 12.335212781
# Mode feat var_143 = 11
# Mean feat var_144 = 8.644855877999998
# Mode feat var_144 = 8
# Mean feat var_145 = 4.8603530180000005
# Mode feat var_145 = 0
# Mean feat var_146 = 10.3622142035
# Mode feat var_146 = 10
# Mean feat var_147 = -3.2382060199999994
# Mode feat var_147 = 0
# Mean feat var_148 = 3.991192569999999
# Mode feat var_148 = 3
# Mean feat var_149 = 5.2762102095
# Mode feat var_149 = 0
# Mean feat var_150 = 16.820051007
# Mode feat var_150 = 15
# Mean feat var_151 = 10.156002283
# Mode feat var_151 = 9
# Mean feat var_152 = 7.628823997500001
# Mode feat var_152 = 7
# Mean feat var_153 = 16.721077255
# Mode feat var_153 = 15
# Mean feat var_154 = 6.971187818500002
# Mode feat var_154 = 7
# Mean feat var_155 = -2.043746718
# Mode feat var_155 = 0
# Mean feat var_156 = 13.208797351500001
# Mode feat var_156 = 13
# Mean feat var_157 = -4.836848327000001
# Mode feat var_157 = 0
# Mean feat var_158 = 17.924734242
# Mode feat var_158 = 15
# Mean feat var_159 = 10.239228836999999
# Mode feat var_159 = 10
# Mean feat var_160 = 24.146181414
# Mode feat var_160 = 18
# Mean feat var_161 = 5.635300462000001
# Mode feat var_161 = 5
# Mean feat var_162 = 5.3609746735
# Mode feat var_162 = 5
# Mean feat var_163 = 11.026376490499999
# Mode feat var_163 = 8
# Mean feat var_164 = -2.8573280249999997
# Mode feat var_164 = 0
# Mean feat var_165 = 19.3207604395
# Mode feat var_165 = 19
# Mean feat var_166 = 2.9628210525000003
# Mode feat var_166 = 2
# Mean feat var_167 = -4.189133114500001
# Mode feat var_167 = 0
# Mean feat var_168 = 4.930355953
# Mode feat var_168 = 4
# Mean feat var_169 = 5.6337155889999995
# Mode feat var_169 = 5
# Mean feat var_170 = -0.020823593000000005
# Mode feat var_170 = 0
# Mean feat var_171 = -0.8051477290000002
# Mode feat var_171 = 0
# Mean feat var_172 = 19.779527723999994
# Mode feat var_172 = 17
# Mean feat var_173 = -0.6662404275000001
# Mode feat var_173 = 0
# Mean feat var_174 = 20.264134910500005
# Mode feat var_174 = 18
# Mean feat var_175 = 11.635714910500003
# Mode feat var_175 = 11
# Mean feat var_176 = -2.7761342174999997
# Mode feat var_176 = 0
# Mean feat var_177 = 11.864537785500003
# Mode feat var_177 = 10
# Mean feat var_178 = -0.9493176000000001
# Mode feat var_178 = 0
# Mean feat var_179 = 2.5826036624999995
# Mode feat var_179 = 0
# Mean feat var_180 = -2.7226357145
# Mode feat var_180 = 0
# Mean feat var_181 = 10.080827214500003
# Mode feat var_181 = 9
# Mean feat var_182 = 0.6514315805000002
# Mode feat var_182 = 0
# Mean feat var_183 = 8.768929472000002
# Mode feat var_183 = 6
# Mean feat var_184 = 12.719302336499998
# Mode feat var_184 = 0
# Mean feat var_185 = -3.9630449140000006
# Mode feat var_185 = 0
# Mean feat var_186 = 8.978800128
# Mode feat var_186 = 8
# Mean feat var_187 = -10.2919186855
# Mode feat var_187 = 0
# Mean feat var_188 = 15.366094265000001
# Mode feat var_188 = 13
# Mean feat var_189 = 0.7556731605000002
# Mode feat var_189 = 0
# Mean feat var_190 = 3.1897662904999993
# Mode feat var_190 = 0
# Mean feat var_191 = 7.458269406000001
# Mode feat var_191 = 8
# Mean feat var_192 = 1.9259441479999997
# Mode feat var_192 = 0
# Mean feat var_193 = 3.3220156865000003
# Mode feat var_193 = 0
# Mean feat var_194 = 17.996966972
# Mode feat var_194 = 18
# Mean feat var_195 = -0.1336569455
# Mode feat var_195 = 0
# Mean feat var_196 = 2.2908987004999997
# Mode feat var_196 = 0
# Mean feat var_197 = 8.912428147499998
# Mode feat var_197 = 8
# Mean feat var_198 = 15.8691836065
# Mode feat var_198 = 16
# Mean feat var_199 = -3.246341973
# Mode feat var_199 = 0
# Mean feat var_0 = 10.679914251999998
# Mode feat var_0 = 9
# Mean feat var_1 = -1.6276216895
# Mode feat var_1 = 0
# Mean feat var_2 = 10.715191851000002
# Mode feat var_2 = 9
# Mean feat var_3 = 6.796529157
# Mode feat var_3 = 7
# Mean feat var_4 = 11.078333240500001
# Mode feat var_4 = 11
# Mean feat var_5 = -5.0653174935
# Mode feat var_5 = 0
# Mean feat var_6 = 5.4089486815
# Mode feat var_6 = 5
# Mean feat var_7 = 16.545849889499998
# Mode feat var_7 = 15
# Mean feat var_8 = 0.28416185
# Mode feat var_8 = 0
# Mean feat var_9 = 7.567236361499998
# Mode feat var_9 = 7
# Mean feat var_10 = 0.3943404409999998
# Mode feat var_10 = 0
# Mean feat var_11 = -3.2455960884999997
# Mode feat var_11 = 0
# Mean feat var_12 = 14.023977798499999
# Mode feat var_12 = 14
# Mean feat var_13 = 8.530232378999997
# Mode feat var_13 = 8
# Mean feat var_14 = 7.5376061135000025
# Mode feat var_14 = 7
# Mean feat var_15 = 14.573125859000001
# Mode feat var_15 = 14
# Mean feat var_16 = 9.333264182500002
# Mode feat var_16 = 8
# Mean feat var_17 = -5.696731002
# Mode feat var_17 = 0
# Mean feat var_18 = 15.244013001999999
# Mode feat var_18 = 15
# Mean feat var_19 = 12.438567329499998
# Mode feat var_19 = 13
# Mean feat var_20 = 13.2908941205
# Mode feat var_20 = 9
# Mean feat var_21 = 17.257882793000004
# Mode feat var_21 = 15
# Mean feat var_22 = 4.3054304705
# Mode feat var_22 = 4
# Mean feat var_23 = 3.0195397695000006
# Mode feat var_23 = 3
# Mean feat var_24 = 10.584400070500001
# Mode feat var_24 = 8
# Mean feat var_25 = 13.667496002999997
# Mode feat var_25 = 13
# Mean feat var_26 = -4.055133277
# Mode feat var_26 = 0
# Mean feat var_27 = -1.1379075224999997
# Mode feat var_27 = 0
# Mean feat var_28 = 5.53297958
# Mode feat var_28 = 5
# Mean feat var_29 = 5.0538735589999995
# Mode feat var_29 = 4
# Mean feat var_30 = -7.6877395945000035
# Mode feat var_30 = 0
# Mean feat var_31 = 10.393045872000002
# Mode feat var_31 = 10
# Mean feat var_32 = -0.5128855335
# Mode feat var_32 = 0
# Mean feat var_33 = 14.7741467185
# Mode feat var_33 = 12
# Mean feat var_34 = 11.434249707999998
# Mode feat var_34 = 11
# Mean feat var_35 = 3.8424991540000004
# Mode feat var_35 = 0
# Mean feat var_36 = 2.1872295715000005
# Mode feat var_36 = 0
# Mean feat var_37 = 5.868899321000001
# Mode feat var_37 = 6
# Mean feat var_38 = 10.642130851000001
# Mode feat var_38 = 10
# Mean feat var_39 = 0.6629564005
# Mode feat var_39 = 0
# Mean feat var_40 = -6.725505203
# Mode feat var_40 = 0
# Mean feat var_41 = 9.299858002
# Mode feat var_41 = 8
# Mean feat var_42 = 11.222356093500002
# Mode feat var_42 = 11
# Mean feat var_43 = 11.5699539
# Mode feat var_43 = 11
# Mean feat var_44 = 8.948288796500002
# Mode feat var_44 = 10
# Mean feat var_45 = -12.6996668205
# Mode feat var_45 = 0
# Mean feat var_46 = 11.326487955999998
# Mode feat var_46 = 11
# Mean feat var_47 = -12.471737158499996
# Mode feat var_47 = 0
# Mean feat var_48 = 14.7047127185
# Mode feat var_48 = 0
# Mean feat var_49 = 16.6824987025
# Mode feat var_49 = 17
# Mean feat var_50 = 12.740985916
# Mode feat var_50 = 12
# Mean feat var_51 = 13.428911726
# Mode feat var_51 = 14
# Mean feat var_52 = -2.5288156159999997
# Mode feat var_52 = 0
# Mean feat var_53 = 6.0085688
# Mode feat var_53 = 6
# Mean feat var_54 = 1.137116864
# Mode feat var_54 = 0
# Mean feat var_55 = 12.745851658000001
# Mode feat var_55 = 11
# Mean feat var_56 = 16.629164889000002
# Mode feat var_56 = 15
# Mean feat var_57 = 6.2720135159999995
# Mode feat var_57 = 6
# Mean feat var_58 = 3.1776331530000004
# Mode feat var_58 = 0
# Mean feat var_59 = 8.9311241245
# Mode feat var_59 = 8
# Mean feat var_60 = 12.155618231499998
# Mode feat var_60 = 13
# Mean feat var_61 = -11.946744154000001
# Mode feat var_61 = 0
# Mean feat var_62 = 0.8741702705000001
# Mode feat var_62 = 0
# Mean feat var_63 = 0.6611733995
# Mode feat var_63 = 0
# Mean feat var_64 = 6.369157323000001
# Mode feat var_64 = 6
# Mean feat var_65 = 0.9828914824999998
# Mode feat var_65 = 0
# Mean feat var_66 = 5.7940388985
# Mode feat var_66 = 5
# Mean feat var_67 = 11.943223381000001
# Mode feat var_67 = 11
# Mean feat var_68 = 5.018893456000002
# Mode feat var_68 = 5
# Mean feat var_69 = -3.3315150865000005
# Mode feat var_69 = 0
# Mean feat var_70 = 24.446811051000005
# Mode feat var_70 = 22
# Mean feat var_71 = 0.669755893
# Mode feat var_71 = 0
# Mean feat var_72 = 0.6405532485
# Mode feat var_72 = 0
# Mean feat var_73 = 19.610887772499996
# Mode feat var_73 = 15
# Mean feat var_74 = 19.518845928
# Mode feat var_74 = 17
# Mean feat var_75 = 16.853731765000003
# Mode feat var_75 = 17
# Mean feat var_76 = 6.050871454
# Mode feat var_76 = 0
# Mean feat var_77 = 19.066992556
# Mode feat var_77 = 17
# Mean feat var_78 = 5.349479312499999
# Mode feat var_78 = 6
# Mean feat var_79 = 14.402136341500002
# Mode feat var_79 = 14
# Mean feat var_80 = 5.795043557000002
# Mode feat var_80 = 0
# Mean feat var_81 = 14.7190238585
# Mode feat var_81 = 15
# Mean feat var_82 = -3.4712732400000004
# Mode feat var_82 = 0
# Mean feat var_83 = 1.0258167765000001
# Mode feat var_83 = 0
# Mean feat var_84 = -2.5902087600000003
# Mode feat var_84 = 0
# Mean feat var_85 = 18.362720644499994
# Mode feat var_85 = 16
# Mean feat var_86 = 5.6210584225
# Mode feat var_86 = 0
# Mean feat var_87 = 11.351483195500002
# Mode feat var_87 = 11
# Mean feat var_88 = 8.702923521499999
# Mode feat var_88 = 7
# Mean feat var_89 = 3.7252079274999996
# Mode feat var_89 = 0
# Mean feat var_90 = -16.548147024000002
# Mode feat var_90 = 0
# Mean feat var_91 = 6.9875414695
# Mode feat var_91 = 6
# Mean feat var_92 = 12.739578443
# Mode feat var_92 = 12
# Mean feat var_93 = 10.556739837000002
# Mode feat var_93 = 10
# Mean feat var_94 = 10.999161667
# Mode feat var_94 = 10
# Mean feat var_95 = -0.084344253
# Mode feat var_95 = 0
# Mean feat var_96 = 14.400433117
# Mode feat var_96 = 14
# Mean feat var_97 = 18.5396446215
# Mode feat var_97 = 0
# Mean feat var_98 = 1.7520119760000004
# Mode feat var_98 = 1
# Mean feat var_99 = -0.7462960345000001
# Mode feat var_99 = 0
# Mean feat var_100 = -6.600518324500001
# Mode feat var_100 = 0
# Mean feat var_101 = 13.4135261765
# Mode feat var_101 = 12
# Mean feat var_102 = 22.294908152
# Mode feat var_102 = 23
# Mean feat var_103 = 1.5683925405
# Mode feat var_103 = 1
# Mean feat var_104 = 11.509834017999996
# Mode feat var_104 = 11
# Mean feat var_105 = 4.244743821
# Mode feat var_105 = 4
# Mean feat var_106 = 8.617657006000002
# Mode feat var_106 = 8
# Mean feat var_107 = 17.7962655475
# Mode feat var_107 = 16
# Mean feat var_108 = 14.224435357
# Mode feat var_108 = 14
# Mean feat var_109 = 18.4580011445
# Mode feat var_109 = 15
# Mean feat var_110 = 5.513238000999999
# Mode feat var_110 = 4
# Mean feat var_111 = 6.312602913999998
# Mode feat var_111 = 6
# Mean feat var_112 = 3.3178433450000004
# Mode feat var_112 = 4
# Mean feat var_113 = 8.136541668
# Mode feat var_113 = 7
# Mean feat var_114 = 3.0811911915000003
# Mode feat var_114 = 3
# Mean feat var_115 = 2.2137167265
# Mode feat var_115 = 0
# Mean feat var_116 = 2.4025696590000005
# Mode feat var_116 = 2
# Mean feat var_117 = 16.102233313000003
# Mode feat var_117 = 0
# Mean feat var_118 = -5.3051323629999985
# Mode feat var_118 = 0
# Mean feat var_119 = 3.032848598
# Mode feat var_119 = 0
# Mean feat var_120 = 24.521077860500007
# Mode feat var_120 = 23
# Mean feat var_121 = 11.310591073500001
# Mode feat var_121 = 10
# Mean feat var_122 = 1.1929837194999995
# Mode feat var_122 = 0
# Mean feat var_123 = 7.076253564999999
# Mode feat var_123 = 0
# Mean feat var_124 = 4.2727401095
# Mode feat var_124 = 4
# Mean feat var_125 = 12.489164999000002
# Mode feat var_125 = 12
# Mean feat var_126 = 13.202325819000004
# Mode feat var_126 = 13
# Mean feat var_127 = 0.8515071519999999
# Mode feat var_127 = 0
# Mean feat var_128 = -1.1279520465
# Mode feat var_128 = 0
# Mean feat var_129 = 15.4603143455
# Mode feat var_129 = 15
# Mean feat var_130 = 12.257150888500004
# Mode feat var_130 = 12
# Mean feat var_131 = 0.5446735375
# Mode feat var_131 = 0
# Mean feat var_132 = 7.799675918000002
# Mode feat var_132 = 7
# Mean feat var_133 = 6.813270463
# Mode feat var_133 = 6
# Mean feat var_134 = -4.826052545999999
# Mode feat var_134 = 0
# Mean feat var_135 = -4.2594721635
# Mode feat var_135 = 0
# Mean feat var_136 = 22.968601605000003
# Mode feat var_136 = 24
# Mean feat var_137 = 17.613651327499998
# Mode feat var_137 = 14
# Mean feat var_138 = 1.2107915105
# Mode feat var_138 = 0
# Mean feat var_139 = 7.760193281
# Mode feat var_139 = 0
# Mean feat var_140 = 3.423636422
# Mode feat var_140 = 0
# Mean feat var_141 = 2.8975962195
# Mode feat var_141 = 0
# Mean feat var_142 = 11.983488539999998
# Mode feat var_142 = 10
# Mean feat var_143 = 12.333697980500004
# Mode feat var_143 = 11
# Mean feat var_144 = 8.647631575
# Mode feat var_144 = 8
# Mean feat var_145 = 4.8413275285
# Mode feat var_145 = 0
# Mean feat var_146 = 10.3411778935
# Mode feat var_146 = 10
# Mean feat var_147 = -3.300779141
# Mode feat var_147 = 0
# Mean feat var_148 = 3.990725669
# Mode feat var_148 = 3
# Mean feat var_149 = 5.2962367200000005
# Mode feat var_149 = 0
# Mean feat var_150 = 16.817671238000003
# Mode feat var_150 = 15
# Mean feat var_151 = 10.141541544499997
# Mode feat var_151 = 9
# Mean feat var_152 = 7.633199000499999
# Mode feat var_152 = 7
# Mean feat var_153 = 16.727902174999997
# Mode feat var_153 = 15
# Mean feat var_154 = 6.974954836999999
# Mode feat var_154 = 7
# Mean feat var_155 = -2.074127825
# Mode feat var_155 = 0
# Mean feat var_156 = 13.209272123499996
# Mode feat var_156 = 13
# Mean feat var_157 = -4.813551722999999
# Mode feat var_157 = 0
# Mean feat var_158 = 17.914590597500002
# Mode feat var_158 = 15
# Mean feat var_159 = 10.223282276499999
# Mode feat var_159 = 10
# Mean feat var_160 = 24.259300121
# Mode feat var_160 = 16
# Mean feat var_161 = 5.633292535999999
# Mode feat var_161 = 5
# Mean feat var_162 = 5.3628964985
# Mode feat var_162 = 5
# Mean feat var_163 = 11.002169658000001
# Mode feat var_163 = 13
# Mean feat var_164 = -2.8719062955
# Mode feat var_164 = 0
# Mean feat var_165 = 19.315753234000002
# Mode feat var_165 = 18
# Mean feat var_166 = 2.9633350695000003
# Mode feat var_166 = 2
# Mean feat var_167 = -4.1511545325
# Mode feat var_167 = 0
# Mean feat var_168 = 4.937123965499999
# Mode feat var_168 = 4
# Mean feat var_169 = 5.636008345
# Mode feat var_169 = 5
# Mean feat var_170 = -0.004962060499999994
# Mode feat var_170 = 0
# Mean feat var_171 = -0.8317765935
# Mode feat var_171 = 0
# Mean feat var_172 = 19.817093824999997
# Mode feat var_172 = 19
# Mean feat var_173 = -0.6779670025
# Mode feat var_173 = 0
# Mean feat var_174 = 20.210676787999997
# Mode feat var_174 = 18
# Mean feat var_175 = 11.640612669500003
# Mode feat var_175 = 11
# Mean feat var_176 = -2.7995846820000008
# Mode feat var_176 = 0
# Mean feat var_177 = 11.8829333875
# Mode feat var_177 = 10
# Mean feat var_178 = -1.0140635939999998
# Mode feat var_178 = 0
# Mean feat var_179 = 2.59144367
# Mode feat var_179 = 0
# Mean feat var_180 = -2.7416661244999996
# Mode feat var_180 = 0
# Mean feat var_181 = 10.085518355
# Mode feat var_181 = 9
# Mean feat var_182 = 0.7191090935
# Mode feat var_182 = 0
# Mean feat var_183 = 8.769087543499998
# Mode feat var_183 = 6
# Mean feat var_184 = 12.756676405999999
# Mode feat var_184 = 0
# Mean feat var_185 = -3.9832606964999995
# Mode feat var_185 = 0
# Mean feat var_186 = 8.970274164500001
# Mode feat var_186 = 8
# Mean feat var_187 = -10.335042614
# Mode feat var_187 = 0
# Mean feat var_188 = 15.377174498999999
# Mode feat var_188 = 14
# Mean feat var_189 = 0.7460716689999998
# Mode feat var_189 = 0
# Mean feat var_190 = 3.234439776
# Mode feat var_190 = 0
# Mean feat var_191 = 7.438408336999999
# Mode feat var_191 = 8
# Mean feat var_192 = 1.9278385139999998
# Mode feat var_192 = 0
# Mean feat var_193 = 3.3317736844999994
# Mode feat var_193 = 0
# Mean feat var_194 = 17.993784183000002
# Mode feat var_194 = 16
# Mean feat var_195 = -0.14208843350000003
# Mode feat var_195 = 0
# Mean feat var_196 = 2.3033352435
# Mode feat var_196 = 0
# Mean feat var_197 = 8.9081576835
# Mode feat var_197 = 8
# Mean feat var_198 = 15.870720248
# Mode feat var_198 = 16
# Mean feat var_199 = -3.3265369005000003
# Mode feat var_199 = 0
# Train and test shape: (200000, 210) (200000, 209)
# Fold 0
# Training until validation scores don't improve for 100 rounds.
# [1000]	training's auc: 0.916878	valid_1's auc: 0.891324
# [2000]	training's auc: 0.93273	valid_1's auc: 0.896546
# [3000]	training's auc: 0.944488	valid_1's auc: 0.898644
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-2c2874505db7> in <module>
#      14
#      15 train_df, test_df = process_data(train, test)
# ---> 16 predictions = run_model(train_df, test_df)
#      17 sub = pd.DataFrame({"ID_code": test_df.ID_code.values})
#      18 sub["target"] = predictions
#
# <ipython-input-64-4a75c03ab8fa> in run_model(train_df, test_df)
#      36         trn_data = lgb.Dataset(train_df.iloc[trn_idx][features], label=target.iloc[trn_idx])
#      37         val_data = lgb.Dataset(train_df.iloc[val_idx][features], label=target.iloc[val_idx])
# ---> 38         clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds = 100)
#      39         oof[val_idx] = clf.predict(train_df.iloc[val_idx][features], num_iteration=clf.best_iteration)
#      40         predictions += clf.predict(test_df[features], num_iteration=clf.best_iteration) / folds.n_splits
#
# c:\python\python36\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     216                                     evaluation_result_list=None))
#     217
# --> 218         booster.update(fobj=fobj)
#     219
#     220         evaluation_result_list = []
#
# c:\python\python36\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    1800             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1801                 self.handle,
# -> 1802                 ctypes.byref(is_finished)))
#    1803             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1804             return is_finished.value == 1
#
# KeyboardInterrupt:
